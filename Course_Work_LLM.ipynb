# %% [markdown]
# # Student LLM
# Large language model based on digital documents of my course work during college
# Start with a single course first then scale to semeter...textbooks etc

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import numpy as nu
import tensor_flow

# %%
corpus= read_docx("C:/Users/Data Analyst/Documents/GitHub/MART-Research/THE PREVENTIVE MEDICINE ASPECT OF MARTLIFE DETOX C.docx")

# %%
# Tokenizer 

# Encoder (Character to Integer)
for i in range(len(corpus)):
# Decoder (Integer to Character)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.12.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
