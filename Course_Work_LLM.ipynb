# %% [markdown]
# # Student LLM
# Large language model based on digital documents of my course work during college
# Start with a single course first then scale to semeter...sesion...textbooks etc

# %%
import matplotlib as py
import numpy as nu
import
