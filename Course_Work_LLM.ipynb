# %% [markdown]
# # Student LLM
# Large language model based on digital documents of my course work during college
# Start with a single course first then scale to semeter...textbooks etc

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import numpy as nu
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler as ss
from sklearn.linear_model import LogisticRegression as lr
from sklearn.metrics import accuracy_score as acs
from sklearn.metrics import classification_report as cr
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import roc_curve as rc
from sklearn.metrics import roc_auc_score as racs
from sklearn.metrics import precision_score as ps
from sklearn.metrics import recall_score as rs

# %%
corpus= pd.read_docx("C:/Users/Data Analyst/Documents/GitHub/MART-Research/THE PREVENTIVE MEDICINE ASPECT OF MARTLIFE DETOX C.docx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 corpus= pd.read_doc("C:/Users/Data Analyst/Documents/GitHub/MART-Research/THE PREVENTIVE MEDICINE ASPECT OF MARTLIFE DETOX C.docx")
#
# AttributeError: module 'pandas' has no attribute 'read_doc'

# %%
# Tokenizer 

# Encoder (Character to Integer)
for i in range(len(corpus)):
# Decoder (Integer to Character)
