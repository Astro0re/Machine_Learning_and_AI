# %% [markdown]
# # Stite Ranking Model
# Using web scraping, this model takes input of your site and compares it (on account of similarity) to the sites generating the most traffic for that service in that given time.

# %% [markdown]
# To-Do List:
#
# * Web srape user site
# * Site for site traffic ranking
# * Comparison model

# %%
# Import Packages
import os
import numpy as np 
import requests
from bs4 import BeautifulSoup
import keras
import sklearn
from sklearn.feature_extraction import FeatureHasher 
from sklearn.feature_selection import 
from sklearn.preprocessing import LabelEncoder
